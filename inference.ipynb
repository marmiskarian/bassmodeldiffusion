# %%
from bassmodel.visualize.visualize import Visualize

# %%
data_path = 'data/smartphones.csv'

# %%
# Create an instance of the Visualization class
bass_model = Visualize(filename=data_path)

# %%
# Fit the data to the Bass Model
bass_model.fit()
# Out:
# Intercept            121.355848
# cumsales               0.336113
# cum_sales_squared     -0.000019
# dtype: float64

# %%
# Perform predictions
m, p, q = bass_model.predict()

# %%
# Visualize the predicted sales
bass_model.plot_pdf()

# %%
# Visualize the cumulative predicted sales
bass_model.plot_cdf()

# %%
# Display the summary
bass_model.summary()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  sales   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.989
# Method:                 Least Squares   F-statistic:                     562.1
# Date:                Tue, 16 May 2023   Prob (F-statistic):           5.33e-11
# Time:                        21:41:08   Log-Likelihood:                -69.535
# No. Observations:                  13   AIC:                             145.1
# Df Residuals:                      10   BIC:                             146.8
# Df Model:                           2
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept           121.3558     31.490      3.854      0.003      51.192     191.519
# cumsales              0.3361      0.014     23.654      0.000       0.304       0.368
# cum_sales_squared -1.873e-05   1.13e-06    -16.592      0.000   -2.12e-05   -1.62e-05
# ==============================================================================
# Omnibus:                        1.242   Durbin-Watson:                   0.736
# Prob(Omnibus):                  0.537   Jarque-Bera (JB):                0.743
# Skew:                          -0.028   Prob(JB):                        0.690
# Kurtosis:                       1.830   Cond. No.                     1.37e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.37e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# ==============================================================================
#
# Coefficient of Innovation (p):          0.00663
# Coefficient of Imitation (q):           0.34275
# Max Adopters (m):                       18297.693
# ==============================================================================
# /Users/maria/anaconda3/envs/bass/lib/python3.10/site-packages/scipy/stats/_stats_py.py:1736: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=13
#   warnings.warn("kurtosistest only valid for n>=20 ... continuing "

# %%
# Print the predicted and actual peak periods
bass_model.print_peak_periods()
# Out:
# ==============================================================================
# Predicted peak sales period:            11.292
# Actual peak sales period:               10
# ==============================================================================
